# %% [markdown]
# # Install Independences

# %%
# Import os to navigate into directory
import os
# Import cv2 to manipulate the img
import cv2
# Import imghdr to see the type of img
import imghdr #
# Import matplotlib to visualize the img
import matplotlib.pyplot as plt
# Import numpy to manipulate array
import numpy as np
import random, shutil
import pydot #
import graphviz #
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_13820\863090557.py:6: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr #

# %%
# Import tensorflow to construct the neural network
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout #
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau #
from keras.regularizers import l2
from keras import applications #
from keras.utils import plot_model #
from keras.preprocessing import image #
from keras.models import load_model #

import visualkeras

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # Pre-Processing Data: Splitting

# %%
def create_ValidationSet(data_path):
    #creating test dataset from the train dataset
    dir_path=data_path
    classes = os.listdir(dir_path)
    
    # creating train directory 
    train_dir = data_path+"/Pokemon_train"
    os.system("mkdir " +train_dir)

    #moving all folders from root folder to train folder
    os.sytem("mv " + dir_path+"/* " + train_dir)

    val_dir = data_path+"/Pokemon_validation"
    os.system("mkdir " +val_dir)

    #copying all train data to test folder, in order to get same folder structure
    os.system("cp -r "+ train_dir+ "/*" + val_dir)
    #deleting images from sub directories of test folder
    os.system("find " + val_dir + "/ -name '*.*' -type f -delete")

    return "Done we split the dataset into training set and validation set"

# %%
# Copying 15 random images from train folders to test folders
def prep_test_data(pokemon, train_dir, test_dir):
  pop = os.listdir(train_dir+'/'+pokemon)
  test_data=random.sample(pop, 15)
  for f in test_data:
    shutil.copy(train_dir+'/'+pokemon+'/'+f, test_dir+'/'+pokemon+'/')

def loop_prep(train_dir, test_dir):
  #performing samething for each folder in train folder
  for poke in os.listdir(train_dir):
    prep_test_data(poke, train_dir, test_dir)

# %%
# UN ALTRO MODO è FARE LO SPLITTING DEL 20%
def create_path(path):
  train_dir = path+"/Pokemon_train"
  test_dir =  path+"/Pokemon_test"
  os.system("mkdir " +train_dir)
  os.system("mkdir " +test_dir)
  return train_dir, test_dir

def splitting(data_path, train_path, test_path, perc):
  
  # folders Pokemon
  fold = sorted(os.listdir(data_path))
  for f in fold:
    # Take the pokemon directory by data_path
    pok_dir = data_path+ f + '/'

    # CREATE POKEMON FOLDER IN THE TEST SET
    if not os.path.isdir(test_path+f):
      os.makedirs(test_path+f)
    pok_file = os.listdir(data_path+f) # list with image of pokemon
  
    # Number of pokemon for the test set
    num_test = round(len(pok_file)* perc)
    # select randomly the image of pokemon for the test set
    img_pok_test = random.sample(pok_file, num_test)

    # We move the image into test set
    for pok_test in img_pok_test:
      shutil.move(pok_dir + pok_test, test_path + f + '/'+ pok_test )

    # CREATE POKEMON FOLDER IN THE TRAIN SET
    if not os.path.isdir(train_path+f):
      os.makedirs(train_path+f)
    
    pok_file = os.listdir(data_path+f) # list with image of pokemon
    # We move the remaining image into train set
    for pok_train in pok_file:
      shutil.move(pok_dir+ pok_train, train_path+f+'/'+pok_train)
      
  return  "Done we split the dataset into training set and validation set"

# %% [markdown]
# # DataLoader

# %%
def data_load(train_dir, validation_dir, image_size, num_batch):
    # Process Data Augmentation
    datagen=ImageDataGenerator(rescale = 1./255,
                           shear_range=0.2,
                           zoom_range=0.2,
                           horizontal_flip=True,
                           )
    
    print('------ Loading TRAIN SET -------')
    training_set=datagen.flow_from_directory(train_dir,
                                         target_size=(image_size[0], image_size[1]),
                                         batch_size=num_batch,
                                         class_mode='categorical',
                                         color_mode='rgb'
                                         )
    
    print('\n\n------ Loading VALIDATION SET ------')
    validation_set=datagen.flow_from_directory(validation_dir,
                                           target_size=(image_size[0], image_size[1]),
                                           batch_size=num_batch,
                                           class_mode='categorical',
                                           color_mode='rgb'
                                           )
    return training_set, validation_set

# %% [markdown]
# ## Visualize Image

# %%
def vis_img(train_generator):
    for each in train_generator:
        img , label = each
        train_batch = each[0]
        labels= each[1]
        break

    plt.imshow(train_batch[0])
    plt.title(np.argmax(labels[0]))

# %% [markdown]
# # Auxiliary Functions

# %% [markdown]
# ## Training

# %%
def train_model(model, train_set, val_set, early_stopping, pat, num_model, num_epochs):
    # Apply early stop --> to predict overfitting case
    es = None
    if early_stopping == True:
        es = EarlyStopping(monitor='val_loss',
                           mode='min', 
                           patience=pat,
                           restore_best_weights = True,
                           verbose=1
                           )
        # Create a File Pre trained
        filepath = "model"+str(num_model)+".h5"
        # Checkpoint of file
        ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
        # Fit the model with respect to training and validation generator
        history = model.fit_generator(generator=train_set, 
                                      validation_data= val_set,
                                      callbacks=[es, ckpt],
                                      epochs = num_epochs )
        
    else:
        filepath = "model"+str(num_model)+".h5"
        # Checkpoint of file
        ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
        # Fit the model with respect to training and validation generator
        history = model.fit_generator(generator=train_set, 
                                      validation_data= val_set,
                                      callbacks=[ckpt],
                                      epochs = num_epochs)
    return history, filepath, es

# %% [markdown]
# ## Accuracy and Loss Functions

# %%
# Define Loss Functions
def loss_function(hist):
    fig = plt.figure()
    plt.plot(hist.history['loss'], color='teal', label='loss')
    plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
    fig.suptitle('Loss', fontsize=20)
    plt.legend(loc="upper left")
    plt.show()


def accuracy_function(hist):
    fig = plt.figure()
    plt.plot(hist.history['acc'], color='teal', label='accuracy')
    plt.plot(hist.history['val_acc'], color='orange', label='val_accuracy')
    fig.suptitle('Accuracy', fontsize=20)
    plt.legend(loc="upper left")
    plt.show()

def plot_history(hist):
    loss_function(hist)
    accuracy_function(hist)

# %% [markdown]
# ## Make Prediction

# %%
def make_prediction(model,
                    train_set, 
                    scale,
                    test_file):
    diz={v:k for k,v in train_set.class_indices.items()}

    test_img = cv2.imread(test_file)
    test_img = cv2.resize(test_img, scale)
    test_img= cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
    plt.imshow(test_img)

    #test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis=0)
    test_img = test_img/255
    #plt.imshow(test_img)

    prediction_prob = model.predict(test_img)
    classes_x=np.argmax(prediction_prob,axis=1)
    plt.title(diz[classes_x[0]])

# %% [markdown]
# # Model 1

# %% [markdown]
# Image with 64 x 64 x 3

# %%
#defining model
def cnn(image_size, num_classes):
    # Reset sezione
    tf.keras.backend.clear_session()
    tf.keras.backend.reset_uids()

    classifier = Sequential()
    classifier.add(Conv2D(64, (5, 5), input_shape=image_size, activation='relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))
    classifier.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))
    classifier.add(Flatten())
    classifier.add(Dense(num_classes, activation = 'softmax'))
    classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return classifier

# %%
train_dir = '/Users/leonardvincentramil/Desktop/Project/Pokemon5/PokemonData/Pokemon_train'
test_dir = '/Users/leonardvincentramil/Desktop/Project/Pokemon5/PokemonData/Pokemon_validation'
img_size1 = (64, 64, 3)
batch_siz1 = 32
num_classes = 149

# %%
neuralnetwork_cnn = cnn(img_size1, num_classes= 149)
neuralnetwork_cnn.summary()
# Visualizzazione modello Baseline
tf.keras.utils.plot_model(neuralnetwork_cnn, show_shapes=True, rankdir= 'LR')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        4864
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 149)               4882581
#
# =================================================================
# Total params: 4,961,301
# Trainable params: 4,961,301
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
visualkeras.layered_view(neuralnetwork_cnn, legend = True, spacing = 30)
# Out:
# <PIL.Image.Image image mode=RGBA size=716x378>

# %%
train_set1 , val_set1 = data_load(train_dir = train_dir,
                                validation_dir = test_dir, 
                                image_size=img_size1,
                                num_batch= batch_siz1)
# Out:
# ------ Loading TRAIN SET -------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_set1 , val_set1 = data_load(train_dir = train_dir,
#       2                                 validation_dir = test_dir,
#       3                                 image_size=img_size1,
#       4                                 num_batch= batch_siz1)
#
# Cell In[9], line 10, in data_load(train_dir, validation_dir, image_size, num_batch)
#       3 datagen=ImageDataGenerator(rescale = 1./255,
#       4                        shear_range=0.2,
#       5                        zoom_range=0.2,
#       6                        horizontal_flip=True,
#       7                        )
#       9 print('------ Loading TRAIN SET -------')
# ---> 10 training_set=datagen.flow_from_directory(train_dir,
#      11                                      target_size=(image_size[0], image_size[1]),
#      12                                      batch_size=num_batch,
#      13                                      class_mode='categorical',
#      14                                      color_mode='rgb'
#      15                                      )
#      17 print('\n\n------ Loading VALIDATION SET ------')
#      18 validation_set=datagen.flow_from_directory(validation_dir,
#      19                                        target_size=(image_size[0], image_size[1]),
#      20                                        batch_size=num_batch,
#      21                                        class_mode='categorical',
#      22                                        color_mode='rgb'
#      23                                        )
#
# File c:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\preprocessing\image.py:1648, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1562 def flow_from_directory(
#    1563     self,
#    1564     directory,
#    (...)
#    1578     keep_aspect_ratio=False,
#    1579 ):
#    1580     """Takes the path to a directory & generates batches of augmented data.
#    1581
#    1582     Args:
#    (...)
#    1646             and `y` is a numpy array of corresponding labels.
#    1647     """
# -> 1648     return DirectoryIterator(
#    1649         directory,
#    1650         self,
#    1651         target_size=target_size,
#    1652         color_mode=color_mode,
#    1653         keep_aspect_ratio=keep_aspect_ratio,
#    1654         classes=classes,
#    1655         class_mode=class_mode,
#    1656         data_format=self.data_format,
#    1657         batch_size=batch_size,
#    1658         shuffle=shuffle,
#    1659         seed=seed,
#    1660         save_to_dir=save_to_dir,
#    1661         save_prefix=save_prefix,
#    1662         save_format=save_format,
#    1663         follow_links=follow_links,
#    1664         subset=subset,
#    1665         interpolation=interpolation,
#    1666         dtype=self.dtype,
#    1667     )
#
# File c:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\preprocessing\image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/Users/leonardvincentramil/Desktop/Project/Pokemon5/PokemonData/Pokemon_train'

# %%
hist1 , fil1, es1 = train_model(model=neuralnetwork_cnn, 
                                train_set= train_set1, 
                                val_set= val_set1, 
                                early_stopping= True,
                                pat= 7, 
                                num_model=1, 
                                num_epochs= 20) # meglio che arrivi a 20
# Out:
# Epoch 1/20
# /var/folders/m9/pqjzxxq91zq6tyyywn2gnx740000gn/T/ipykernel_14644/256571734.py:16: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_set,
# 211/212 [============================>.] - ETA: 0s - loss: 4.4813 - acc: 0.0725
# Epoch 1: loss improved from inf to 4.47690, saving model to model1.h5
# 212/212 [==============================] - 20s 93ms/step - loss: 4.4769 - acc: 0.0730 - val_loss: 3.2772 - val_acc: 0.2734
# Epoch 2/20
# 212/212 [==============================] - ETA: 0s - loss: 2.9172 - acc: 0.3231
# Epoch 2: loss improved from 4.47690 to 2.91722, saving model to model1.h5
# 212/212 [==============================] - 20s 92ms/step - loss: 2.9172 - acc: 0.3231 - val_loss: 2.2361 - val_acc: 0.4630
# Epoch 3/20
# 212/212 [==============================] - ETA: 0s - loss: 2.1658 - acc: 0.4775
# Epoch 3: loss improved from 2.91722 to 2.16579, saving model to model1.h5
# 212/212 [==============================] - 20s 93ms/step - loss: 2.1658 - acc: 0.4775 - val_loss: 1.7260 - val_acc: 0.5917
# Epoch 4/20
# 212/212 [==============================] - ETA: 0s - loss: 1.6792 - acc: 0.5818
# Epoch 4: loss improved from 2.16579 to 1.67922, saving model to model1.h5
# 212/212 [==============================] - 20s 92ms/step - loss: 1.6792 - acc: 0.5818 - val_loss: 1.3985 - val_acc: 0.6584
# Epoch 5/20
# 212/212 [==============================] - ETA: 0s - loss: 1.3991 - acc: 0.6508
# Epoch 5: loss improved from 1.67922 to 1.39914, saving model to model1.h5
# 212/212 [==============================] - 20s 93ms/step - loss: 1.3991 - acc: 0.6508 - val_loss: 1.1092 - val_acc: 0.7216
# Epoch 6/20
# 212/212 [==============================] - ETA: 0s - loss: 1.1923 - acc: 0.6915
# Epoch 6: loss improved from 1.39914 to 1.19226, saving model to model1.h5
# 212/212 [==============================] - 20s 96ms/step - loss: 1.1923 - acc: 0.6915 - val_loss: 1.0413 - val_acc: 0.7293
# Epoch 7/20
# 212/212 [==============================] - ETA: 0s - loss: 1.0374 - acc: 0.7256
# Epoch 7: loss improved from 1.19226 to 1.03738, saving model to model1.h5
# 212/212 [==============================] - 20s 96ms/step - loss: 1.0374 - acc: 0.7256 - val_loss: 0.9015 - val_acc: 0.7714
# Epoch 8/20
# 212/212 [==============================] - ETA: 0s - loss: 0.9059 - acc: 0.7567
# Epoch 8: loss improved from 1.03738 to 0.90590, saving model to model1.h5
# 212/212 [==============================] - 20s 95ms/step - loss: 0.9059 - acc: 0.7567 - val_loss: 0.7328 - val_acc: 0.7974
# Epoch 9/20
# 212/212 [==============================] - ETA: 0s - loss: 0.7652 - acc: 0.7966
# Epoch 9: loss improved from 0.90590 to 0.76517, saving model to model1.h5
# 212/212 [==============================] - 20s 94ms/step - loss: 0.7652 - acc: 0.7966 - val_loss: 0.6341 - val_acc: 0.8310
# Epoch 10/20
# 212/212 [==============================] - ETA: 0s - loss: 0.6772 - acc: 0.8212
# Epoch 10: loss improved from 0.76517 to 0.67718, saving model to model1.h5
# 212/212 [==============================] - 20s 93ms/step - loss: 0.6772 - acc: 0.8212 - val_loss: 0.5426 - val_acc: 0.8669
# Epoch 11/20
# 212/212 [==============================] - ETA: 0s - loss: 0.5936 - acc: 0.8368
# Epoch 11: loss improved from 0.67718 to 0.59356, saving model to model1.h5
# 212/212 [==============================] - 20s 95ms/step - loss: 0.5936 - acc: 0.8368 - val_loss: 0.5046 - val_acc: 0.8539
# Epoch 12/20
# 212/212 [==============================] - ETA: 0s - loss: 0.5267 - acc: 0.8534
# Epoch 12: loss improved from 0.59356 to 0.52669, saving model to model1.h5
# 212/212 [==============================] - 21s 100ms/step - loss: 0.5267 - acc: 0.8534 - val_loss: 0.4386 - val_acc: 0.8853
# Epoch 13/20
# 212/212 [==============================] - ETA: 0s - loss: 0.4734 - acc: 0.8652
# Epoch 13: loss improved from 0.52669 to 0.47339, saving model to model1.h5
# 212/212 [==============================] - 20s 92ms/step - loss: 0.4734 - acc: 0.8652 - val_loss: 0.4461 - val_acc: 0.8705
# Epoch 14/20
# 212/212 [==============================] - ETA: 0s - loss: 0.4449 - acc: 0.8727
# Epoch 14: loss improved from 0.47339 to 0.44487, saving model to model1.h5
# 212/212 [==============================] - 20s 95ms/step - loss: 0.4449 - acc: 0.8727 - val_loss: 0.3493 - val_acc: 0.9036
# Epoch 15/20
# 212/212 [==============================] - ETA: 0s - loss: 0.4135 - acc: 0.8852
# Epoch 15: loss improved from 0.44487 to 0.41351, saving model to model1.h5
# 212/212 [==============================] - 20s 96ms/step - loss: 0.4135 - acc: 0.8852 - val_loss: 0.3291 - val_acc: 0.9041
# Epoch 16/20
# 212/212 [==============================] - ETA: 0s - loss: 0.3645 - acc: 0.8957
# Epoch 16: loss improved from 0.41351 to 0.36454, saving model to model1.h5
# 212/212 [==============================] - 20s 95ms/step - loss: 0.3645 - acc: 0.8957 - val_loss: 0.2658 - val_acc: 0.9242
# Epoch 17/20
# 212/212 [==============================] - ETA: 0s - loss: 0.3468 - acc: 0.9037
# Epoch 17: loss improved from 0.36454 to 0.34681, saving model to model1.h5
# 212/212 [==============================] - 21s 99ms/step - loss: 0.3468 - acc: 0.9037 - val_loss: 0.3157 - val_acc: 0.9099
# Epoch 18/20
# 212/212 [==============================] - ETA: 0s - loss: 0.2995 - acc: 0.9149
# Epoch 18: loss improved from 0.34681 to 0.29955, saving model to model1.h5
# 212/212 [==============================] - 20s 93ms/step - loss: 0.2995 - acc: 0.9149 - val_loss: 0.2528 - val_acc: 0.9242
# Epoch 19/20
# 211/212 [============================>.] - ETA: 0s - loss: 0.2977 - acc: 0.9176
# Epoch 19: loss improved from 0.29955 to 0.29914, saving model to model1.h5
# 212/212 [==============================] - 19s 92ms/step - loss: 0.2991 - acc: 0.9175 - val_loss: 0.2378 - val_acc: 0.9386
# Epoch 20/20
# 212/212 [==============================] - ETA: 0s - loss: 0.2847 - acc: 0.9172
# Epoch 20: loss improved from 0.29914 to 0.28474, saving model to model1.h5
# 212/212 [==============================] - 21s 101ms/step - loss: 0.2847 - acc: 0.9172 - val_loss: 0.2002 - val_acc: 0.9462

# %%
fil1
# Out:
# 'model1.h5'

# %%
plot_history(hist=hist1)

# %%
make_prediction(model= neuralnetwork_cnn,
                train_set = train_set1, 
                scale= (64,64),
                test_file= '/Users/leonardvincentramil/Desktop/Screenshot 2023-08-12 alle 18.26.52.png')
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %% [markdown]
# # Model 2

# %%
img_size2 = (128, 128, 3)
batch_siz2 = 32
num_classes = 149

# %%
train_set2 , val_set2 = data_load(train_dir = train_dir,
                                validation_dir = test_dir, 
                                image_size=img_size2,
                                num_batch= batch_siz2)
# Out:
# ------ Loading TRAIN SET -------
# Found 6779 images belonging to 149 classes.
#
#
# ------ Loading VALIDATION SET ------
# Found 2231 images belonging to 149 classes.

# %%
#Defining model
def cnn2(image_size, num_classes):
    classifier = Sequential()
    classifier.add(Conv2D(64, (5, 5), input_shape=image_size, activation='relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))

    classifier.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))

    classifier.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))
    
    classifier.add(Flatten())
    classifier.add(Dense(num_classes, activation = 'softmax'))
    classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return classifier

neuralnetwork_cnn2 = cnn2(img_size2, num_classes= 149)
neuralnetwork_cnn2.summary()
#plot_model(neuralnetwork_cnn2, show_shapes=True) # just learned this nice new thing
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      4864
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 149)               4882581
#
# =================================================================
# Total params: 5,108,885
# Trainable params: 5,108,885
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist2 , fil2, es2 = train_model(model=neuralnetwork_cnn2, 
                                train_set= train_set2, 
                                val_set= val_set2, 
                                early_stopping= True,
                                pat= 7, 
                                num_model=2, 
                                num_epochs= 50)
# Out:
# Epoch 1/50
# /var/folders/m9/pqjzxxq91zq6tyyywn2gnx740000gn/T/ipykernel_12686/256571734.py:16: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_set,
# 212/212 [==============================] - ETA: 0s - loss: 4.4547 - acc: 0.0761
# Epoch 1: loss improved from inf to 4.45471, saving model to model2.h5
# 212/212 [==============================] - 37s 169ms/step - loss: 4.4547 - acc: 0.0761 - val_loss: 3.3157 - val_acc: 0.2488
# Epoch 2/50
# 212/212 [==============================] - ETA: 0s - loss: 2.9046 - acc: 0.3192
# Epoch 2: loss improved from 4.45471 to 2.90460, saving model to model2.h5
# 212/212 [==============================] - 35s 165ms/step - loss: 2.9046 - acc: 0.3192 - val_loss: 2.2257 - val_acc: 0.4666
# Epoch 3/50
# 212/212 [==============================] - ETA: 0s - loss: 2.1226 - acc: 0.4802
# Epoch 3: loss improved from 2.90460 to 2.12261, saving model to model2.h5
# 212/212 [==============================] - 35s 166ms/step - loss: 2.1226 - acc: 0.4802 - val_loss: 1.6215 - val_acc: 0.5957
# Epoch 4/50
# 212/212 [==============================] - ETA: 0s - loss: 1.6114 - acc: 0.5908
# Epoch 4: loss improved from 2.12261 to 1.61143, saving model to model2.h5
# 212/212 [==============================] - 35s 164ms/step - loss: 1.6114 - acc: 0.5908 - val_loss: 1.2409 - val_acc: 0.6759
# Epoch 5/50
# 212/212 [==============================] - ETA: 0s - loss: 1.2413 - acc: 0.6769
# Epoch 5: loss improved from 1.61143 to 1.24130, saving model to model2.h5
# 212/212 [==============================] - 36s 167ms/step - loss: 1.2413 - acc: 0.6769 - val_loss: 0.9605 - val_acc: 0.7517
# Epoch 6/50
# 212/212 [==============================] - ETA: 0s - loss: 1.0015 - acc: 0.7361
# Epoch 6: loss improved from 1.24130 to 1.00145, saving model to model2.h5
# 212/212 [==============================] - 35s 165ms/step - loss: 1.0015 - acc: 0.7361 - val_loss: 0.7240 - val_acc: 0.8064
# Epoch 7/50
# 212/212 [==============================] - ETA: 0s - loss: 0.8399 - acc: 0.7718
# Epoch 7: loss improved from 1.00145 to 0.83995, saving model to model2.h5
# 212/212 [==============================] - 35s 165ms/step - loss: 0.8399 - acc: 0.7718 - val_loss: 0.7197 - val_acc: 0.8064
# Epoch 8/50
# 212/212 [==============================] - ETA: 0s - loss: 0.6723 - acc: 0.8146
# Epoch 8: loss improved from 0.83995 to 0.67231, saving model to model2.h5
# 212/212 [==============================] - 35s 166ms/step - loss: 0.6723 - acc: 0.8146 - val_loss: 0.4704 - val_acc: 0.8678
# Epoch 9/50
# 212/212 [==============================] - ETA: 0s - loss: 0.5663 - acc: 0.8422
# Epoch 9: loss improved from 0.67231 to 0.56629, saving model to model2.h5
# 212/212 [==============================] - 35s 165ms/step - loss: 0.5663 - acc: 0.8422 - val_loss: 0.4253 - val_acc: 0.8817
# Epoch 10/50
# 212/212 [==============================] - ETA: 0s - loss: 0.5082 - acc: 0.8596
# Epoch 10: loss improved from 0.56629 to 0.50819, saving model to model2.h5
# 212/212 [==============================] - 35s 167ms/step - loss: 0.5082 - acc: 0.8596 - val_loss: 0.3958 - val_acc: 0.8947
# Epoch 11/50
# 212/212 [==============================] - ETA: 0s - loss: 0.4250 - acc: 0.8743
# Epoch 11: loss improved from 0.50819 to 0.42497, saving model to model2.h5
# 212/212 [==============================] - 36s 168ms/step - loss: 0.4250 - acc: 0.8743 - val_loss: 0.3503 - val_acc: 0.8965
# Epoch 12/50
# 212/212 [==============================] - ETA: 0s - loss: 0.3917 - acc: 0.8936
# Epoch 12: loss improved from 0.42497 to 0.39173, saving model to model2.h5
# 212/212 [==============================] - 36s 171ms/step - loss: 0.3917 - acc: 0.8936 - val_loss: 0.2860 - val_acc: 0.9198
# Epoch 13/50
# 212/212 [==============================] - ETA: 0s - loss: 0.3065 - acc: 0.9140
# Epoch 13: loss improved from 0.39173 to 0.30655, saving model to model2.h5
# 212/212 [==============================] - 37s 176ms/step - loss: 0.3065 - acc: 0.9140 - val_loss: 0.2311 - val_acc: 0.9332
# Epoch 14/50
# 212/212 [==============================] - ETA: 0s - loss: 0.2847 - acc: 0.9174
# Epoch 14: loss improved from 0.30655 to 0.28469, saving model to model2.h5
# 212/212 [==============================] - 37s 172ms/step - loss: 0.2847 - acc: 0.9174 - val_loss: 0.2151 - val_acc: 0.9390
# Epoch 15/50
# 212/212 [==============================] - ETA: 0s - loss: 0.2788 - acc: 0.9205
# Epoch 15: loss improved from 0.28469 to 0.27876, saving model to model2.h5
# 212/212 [==============================] - 38s 177ms/step - loss: 0.2788 - acc: 0.9205 - val_loss: 0.2445 - val_acc: 0.9292
# Epoch 16/50
# 212/212 [==============================] - ETA: 0s - loss: 0.2539 - acc: 0.9295
# Epoch 16: loss improved from 0.27876 to 0.25386, saving model to model2.h5
# 212/212 [==============================] - 38s 177ms/step - loss: 0.2539 - acc: 0.9295 - val_loss: 0.1862 - val_acc: 0.9476
# Epoch 17/50
# 212/212 [==============================] - ETA: 0s - loss: 0.2232 - acc: 0.9361
# Epoch 17: loss improved from 0.25386 to 0.22315, saving model to model2.h5
# 212/212 [==============================] - 38s 180ms/step - loss: 0.2232 - acc: 0.9361 - val_loss: 0.1617 - val_acc: 0.9574
# Epoch 18/50
# 212/212 [==============================] - ETA: 0s - loss: 0.2191 - acc: 0.9382
# Epoch 18: loss improved from 0.22315 to 0.21906, saving model to model2.h5
# 212/212 [==============================] - 37s 175ms/step - loss: 0.2191 - acc: 0.9382 - val_loss: 0.1436 - val_acc: 0.9588
# Epoch 19/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1644 - acc: 0.9513
# Epoch 19: loss improved from 0.21906 to 0.16437, saving model to model2.h5
# 212/212 [==============================] - 36s 169ms/step - loss: 0.1644 - acc: 0.9513 - val_loss: 0.1442 - val_acc: 0.9610
# Epoch 20/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1650 - acc: 0.9498
# Epoch 20: loss did not improve from 0.16437
# 212/212 [==============================] - 36s 168ms/step - loss: 0.1650 - acc: 0.9498 - val_loss: 0.1379 - val_acc: 0.9610
# Epoch 21/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1645 - acc: 0.9488
# Epoch 21: loss did not improve from 0.16437
# 212/212 [==============================] - 36s 168ms/step - loss: 0.1645 - acc: 0.9488 - val_loss: 0.1440 - val_acc: 0.9565
# Epoch 22/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1539 - acc: 0.9555
# Epoch 22: loss improved from 0.16437 to 0.15388, saving model to model2.h5
# 212/212 [==============================] - 36s 169ms/step - loss: 0.1539 - acc: 0.9555 - val_loss: 0.1372 - val_acc: 0.9637
# Epoch 23/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1770 - acc: 0.9501
# Epoch 23: loss did not improve from 0.15388
# 212/212 [==============================] - 36s 172ms/step - loss: 0.1770 - acc: 0.9501 - val_loss: 0.1457 - val_acc: 0.9579
# Epoch 24/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1719 - acc: 0.9547
# Epoch 24: loss did not improve from 0.15388
# 212/212 [==============================] - 36s 172ms/step - loss: 0.1719 - acc: 0.9547 - val_loss: 0.1195 - val_acc: 0.9646
# Epoch 25/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1357 - acc: 0.9618
# Epoch 25: loss improved from 0.15388 to 0.13571, saving model to model2.h5
# 212/212 [==============================] - 36s 169ms/step - loss: 0.1357 - acc: 0.9618 - val_loss: 0.1200 - val_acc: 0.9686
# Epoch 26/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1468 - acc: 0.9588
# Epoch 26: loss did not improve from 0.13571
# 212/212 [==============================] - 35s 165ms/step - loss: 0.1468 - acc: 0.9588 - val_loss: 0.1109 - val_acc: 0.9655
# Epoch 27/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1530 - acc: 0.9569
# Epoch 27: loss did not improve from 0.13571
# 212/212 [==============================] - 36s 167ms/step - loss: 0.1530 - acc: 0.9569 - val_loss: 0.0859 - val_acc: 0.9758
# Epoch 28/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1267 - acc: 0.9649
# Epoch 28: loss improved from 0.13571 to 0.12671, saving model to model2.h5
# 212/212 [==============================] - 39s 182ms/step - loss: 0.1267 - acc: 0.9649 - val_loss: 0.0964 - val_acc: 0.9691
# Epoch 29/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1321 - acc: 0.9615
# Epoch 29: loss did not improve from 0.12671
# 212/212 [==============================] - 38s 180ms/step - loss: 0.1321 - acc: 0.9615 - val_loss: 0.1222 - val_acc: 0.9704
# Epoch 30/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1044 - acc: 0.9736
# Epoch 30: loss improved from 0.12671 to 0.10445, saving model to model2.h5
# 212/212 [==============================] - 38s 181ms/step - loss: 0.1044 - acc: 0.9736 - val_loss: 0.0707 - val_acc: 0.9839
# Epoch 31/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1121 - acc: 0.9668
# Epoch 31: loss did not improve from 0.10445
# 212/212 [==============================] - 37s 175ms/step - loss: 0.1121 - acc: 0.9668 - val_loss: 0.0882 - val_acc: 0.9722
# Epoch 32/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1098 - acc: 0.9686
# Epoch 32: loss did not improve from 0.10445
# 212/212 [==============================] - 37s 172ms/step - loss: 0.1098 - acc: 0.9686 - val_loss: 0.0938 - val_acc: 0.9758
# Epoch 33/50
# 212/212 [==============================] - ETA: 0s - loss: 0.0984 - acc: 0.9711
# Epoch 33: loss improved from 0.10445 to 0.09842, saving model to model2.h5
# 212/212 [==============================] - 35s 164ms/step - loss: 0.0984 - acc: 0.9711 - val_loss: 0.1093 - val_acc: 0.9695
# Epoch 34/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1126 - acc: 0.9690
# Epoch 34: loss did not improve from 0.09842
# 212/212 [==============================] - 35s 164ms/step - loss: 0.1126 - acc: 0.9690 - val_loss: 0.0672 - val_acc: 0.9807
# Epoch 35/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1046 - acc: 0.9714
# Epoch 35: loss did not improve from 0.09842
# 212/212 [==============================] - 37s 172ms/step - loss: 0.1046 - acc: 0.9714 - val_loss: 0.1235 - val_acc: 0.9641
# Epoch 36/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1001 - acc: 0.9718
# Epoch 36: loss did not improve from 0.09842
# 212/212 [==============================] - 36s 168ms/step - loss: 0.1001 - acc: 0.9718 - val_loss: 0.0724 - val_acc: 0.9794
# Epoch 37/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1181 - acc: 0.9681
# Epoch 37: loss did not improve from 0.09842
# 212/212 [==============================] - 35s 165ms/step - loss: 0.1181 - acc: 0.9681 - val_loss: 0.0747 - val_acc: 0.9776
# Epoch 38/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1022 - acc: 0.9720
# Epoch 38: loss did not improve from 0.09842
# 212/212 [==============================] - 35s 164ms/step - loss: 0.1022 - acc: 0.9720 - val_loss: 0.1202 - val_acc: 0.9628
# Epoch 39/50
# 212/212 [==============================] - ETA: 0s - loss: 0.0971 - acc: 0.9764
# Epoch 39: loss improved from 0.09842 to 0.09713, saving model to model2.h5
# 212/212 [==============================] - 35s 164ms/step - loss: 0.0971 - acc: 0.9764 - val_loss: 0.0838 - val_acc: 0.9776
# Epoch 40/50
# 212/212 [==============================] - ETA: 0s - loss: 0.1068 - acc: 0.9684
# Epoch 40: loss did not improve from 0.09713
# 212/212 [==============================] - 35s 164ms/step - loss: 0.1068 - acc: 0.9684 - val_loss: 0.0915 - val_acc: 0.9745
# Epoch 41/50
# 212/212 [==============================] - ETA: 0s - loss: 0.0911 - acc: 0.9746Restoring model weights from the end of the best epoch: 34.
#
# Epoch 41: loss improved from 0.09713 to 0.09106, saving model to model2.h5
# 212/212 [==============================] - 35s 164ms/step - loss: 0.0911 - acc: 0.9746 - val_loss: 0.1206 - val_acc: 0.9686
# Epoch 41: early stopping

# %%
make_prediction(model= neuralnetwork_cnn2,
                train_set = train_set2, 
                scale= (128,128),
                test_file= '/Users/leonardvincentramil/Downloads/Machamp.jpg')
# Out:
# 1/1 [==============================] - 0s 16ms/step
